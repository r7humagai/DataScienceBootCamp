# %%
import pandas as pd
import numpy as np

# %%
path = '/content/Ch2_Q15_V09_Data_File.xlsx'

# %%
df_q6_raw = pd.read_excel(path)

# %%
df_q6_raw.head(10)
df_q6_raw.shape
# Out:
# (186, 8)

# %%
# Cleaning the data
df_q6_clean = df_q6_raw.iloc[0:,0:3]
print(df_q6_clean)

# Check for null values
df_q6_clean.isna().sum()    # No null values
# Out:
#      Student     Sex Feasible
# 0          1  female      yes
# 1          2  female      yes
# 2          3  female      yes
# 3          4  female      yes
# 4          5  female      yes
# ..       ...     ...      ...
# 181      182    male       no
# 182      183    male       no
# 183      184    male       no
# 184      185    male       no
# 185      186    male       no
#
# [186 rows x 3 columns]
# Student     0
# Sex         0
# Feasible    0
# dtype: int64

# %%
df_q6 = df_q6_clean
df_q6
# Out:
#      Student     Sex Feasible
# 0          1  female      yes
# 1          2  female      yes
# 2          3  female      yes
# 3          4  female      yes
# 4          5  female      yes
# ..       ...     ...      ...
# 181      182    male       no
# 182      183    male       no
# 183      184    male       no
# 184      185    male       no
# 185      186    male       no
#
# [186 rows x 3 columns]

# %%
'a-1. Construct a contingency table that cross-classifies the data by Sex and Feasible. Provide the frequencies in the accompanying table.'
df_q6_grouping = df_q6.groupby(['Sex', 'Feasible'], as_index = True).count()
df_q6_grouping
# Out:
#                  Student
# Sex    Feasible
# female no             26
#        yes            74
# male   no             37
#        yes            49

# %%
'a-2. How many of the students were female?'

number_of_female_students = (df_q6['Sex'] == 'female').sum()
print("The students that are female: ",number_of_female_students)
# Out:
# The students that are female:  100

# %%
'a-3. How many of the students felt that it was feasible for men and women to be just friends?'

answer3 = (df_q6['Feasible'] == "yes").sum()
print(answer3, "of the students felt that it was feasible for men and women to be just friends.")
# Out:
# 123 of the students felt that it was feasible for men and women to be just friends.

# %%
'''
b-1. What is the likelihood that a male student feels that men and women can be just friends?
(Report the proportion rounded to 2 decimal places.)
'''
# Calculate the number of male students
number_of_male_students = (df_q6['Sex'] == 'male').sum()

# Calculate the number of students who are Male & Feasible is yes

answerb1 = ((df_q6['Sex'] == 'male') & (df_q6['Feasible'] == 'yes')).sum()

# Calculate a percentage value
likelihood = "{:.2f}".format((answerb1/number_of_male_students) * 100)
print(likelihood, "students of 100 male students feel that men and women can be just friends.")
# Out:
# 56.98 students of 100 male students feel that men and women can be just friends.

# %%
'''
b-2. What is the likelihood that a female student feels that men and women can be just friends?
(Report the proportion rounded to 2 decimal places.)
'''
# Calculate the number of female students
number_of_female_students = (df_q6['Sex'] == 'female').sum()

# Calculate the number of students who are Female & Feasible is yes

answerb2 = ((df_q6['Sex'] == 'female') & (df_q6['Feasible'] == 'yes')).sum()

# Calculate a percentage value
likelihood2 = "{:.2f}".format((answerb2/number_of_female_students) * 100)
print(likelihood2, "students of 100 female students feel that men and women can be just friends.")
# Out:
# 74.00 students of 100 female students feel that men and women can be just friends.
