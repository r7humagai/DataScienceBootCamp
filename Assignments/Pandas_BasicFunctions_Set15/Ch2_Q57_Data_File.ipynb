# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
path = '/content/Ch2_Q57_Data_File.xlsx'

# %%
df_raw = pd.read_excel(path)

# %%
df_raw.head(10)
df_raw.shape
# Out:
# (80, 9)

# %%
# Cleaning the data: Only keeping the relevant columns
df_clean = df_raw.iloc[0: ,0:4]
df_clean.head(5)
# Out:
#    Worker   Wage  Education  Age
# 0       1  17.54         12   76
# 1       2  20.93         10   61
# 2       3  12.94          8   75
# 3       4  19.34          6   38
# 4       5  24.12         12   59

# %%
'''
The manager of a human resources department of a large manufacturing firm gathers data on
the hourly wage (in $), years of education, and age for 80 employees. The accompanying table shows a portion of the data.
'''

# %%
# Question a: Construct a scatterplot of Wage and Education.

plt.style.use('seaborn')

wage = df_clean['Wage']
education = df_clean['Education']
wage_per_education = wage/education

plt.scatter(education, wage, c=wage_per_education, cmap = 'summer', edgecolor = 'black', linewidth = 1, alpha = 0.75)

cbar = plt.colorbar()
cbar.set_label('Wage/Education Ratio')

plt.title('Wage-Education Ratio')
plt.xlabel('Education')
plt.ylabel('Wage')

plt.show()
# Out:
# <ipython-input-18-060089e380cc>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
'''
Question a: Construct a scatterplot of Wage and Education.
Given the scatterplot, which statement best describes the relationship between Wage and Education?
i. Wage and Education have a positive relationship.
ii. Wage and Education have a negative relationship.
iii. Wage and Education have no relationship.
iv. Wage and Education have an inverted U-shaped (nonlinear) relationship.
'''

print("Wage and Education have a positive relation as we can see from the scatterplot, the wage increases as education increases.")
# Out:
# Wage and Education have a positive relation as we can see from the scatterplot, the wage increases as education increases.

# %%
# b. Construct a scatterplot of Wage and Age

plt.style.use('seaborn')

wage = df_clean['Wage']
age = df_clean['Age']
wage_per_age = wage/age

plt.scatter(age, wage, c=wage_per_age, cmap = 'summer', edgecolor = 'black', linewidth = 1, alpha = 0.75)

cbar = plt.colorbar()
cbar.set_label('Wage/Age Ratio')

plt.title('Wage-Age Ratio')
plt.xlabel('Age')
plt.ylabel('Wage')

plt.show()
# Out:
# <ipython-input-19-ac420e4c2f37>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
'''
b. Construct a scatterplot of Wage and Age. Given the scatterplot, which statement best describes the relationship between Wage and Age?
i. Wage and Education have a positive relationship.
ii. Wage and Education have a negative relationship.
iii. Wage and Education have no relationship.
iv. Wage and Education have an inverted U-shaped (nonlinear) relationship.
'''

print("Wage and Education have an inverted U-shaped (nonlinear) relationship.")
# Out:
# Wage and Education have an inverted U-shaped (nonlinear) relationship.
